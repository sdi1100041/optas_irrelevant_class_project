# %%
# %run main.py --task=CIFAR100 --lr=0.001 --epochs=50 --algorithm=Adam --model=ResNet18 --regularization
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
#  [=========================================>.......................]  Step: 94ms | Tot: 3m23s | Loss: 2.257 | Acc: 43.433% (13974/32174) 2054/3204
# ...
